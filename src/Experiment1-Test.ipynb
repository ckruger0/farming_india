# %%
import pandas as pd
import pandas_profiling

# %% [markdown]
# ## Dataset Imports

# %%
state_gdp = pd.read_csv('../data/AnnualStateGDP2018.csv', names=['states','nom_gdp_inr','nom_gdp_usd'], skiprows=1)
out_liab = pd.read_csv('../data/OutstandingLiabilitiesbyState20162017.csv')
#rds = pd.read_csv('../data/Roads_2013.csv')
pov_line = pd.read_csv('../data/Ruralpercentagebelowpovertyline20112012.csv')
default_rt = pd.read_csv('../data/loan_default_rates.csv')
rainfall = pd.read_csv('../data/rainfallyearly.csv')

# %%
pandas_profiling.ProfileReport(state_gdp)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
out_liab.head()
# Out:
#                State Billions of Rupees
# 0     Andhra Pradesh            1,609.0
# 1  Arunachal Pradesh               51.5
# 2              Assam              475.8
# 3              Bihar            1,314.3
# 4       Chhattisgarh              457.8

# %%
len(out_liab['State'].unique())

# %%
pov_line.head()
# Out:
#                State  Percent of rural ppl below poverty line
# 0     Andhra Pradesh                                     11.0
# 1  Arunachal Pradesh                                     38.9
# 2              Assam                                     33.9
# 3              Bihar                                     34.1
# 4       Chhattisgarh                                     44.6

# %%
default_rt.head()
# Out:
#      STATE  YEAR  NPA-LOANS-RATIO  RECOVERY-RATIO
# 0  Haryana  2012            32.32           50.96
# 1  Haryana  2013            29.47           55.68
# 2  Haryana  2014            46.59           32.10
# 3  Haryana  2015            63.44           28.23
# 4  Haryana  2016            73.00           28.23

# %%
rainfall.head()
# Out:
#    Unnamed: 0                subdivision  year    jan   feb    mar    apr  \
# 0         104  ANDAMAN & NICOBAR ISLANDS  2010  101.7   8.0    0.7   12.5
# 1         105  ANDAMAN & NICOBAR ISLANDS  2011  265.9  84.8  272.8  111.4
# 2         106  ANDAMAN & NICOBAR ISLANDS  2012  119.9  45.6   30.9   55.8
# 3         107  ANDAMAN & NICOBAR ISLANDS  2013   67.1  37.6   43.0   46.3
# 4         108  ANDAMAN & NICOBAR ISLANDS  2014   41.9   8.6    0.0   11.1
#
#      may    jun    jul    aug    sep    oct    nov    dec  annual  jan_feb  \
# 0  319.0  448.9  521.9  563.8  263.3  402.4  268.5  246.4  3157.1    109.8
# 1  326.5  383.2  583.2  441.5  757.1  212.3  150.8  238.5  3828.0    350.7
# 2  533.9  458.2  317.3  369.6  868.9  209.7  300.5  187.3  3497.6    165.6
# 3  509.3  777.0  564.8  336.7  473.6  455.8  354.2   92.3  3757.8    104.7
# 4  238.0  416.6  467.6  321.6  412.9  402.6  201.2  100.4  2622.4     50.5
#
#    mar_may  jun_sep  oct_dec
# 0    332.2   1797.8    917.3
# ...

# %% [markdown]
# ## PreProcessing

# %% [markdown]
# ## Join Datasets

# %% [markdown]
# ## Model Selection
